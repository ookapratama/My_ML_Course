# %% [markdown]
# # Exercise - Prediksi GPA (Grade Point Average) atau IPK berdasarkan nilai tes awal siswa (SAT - Schollastic Assement Test)

# %% [markdown]
# ## Deskripsi
# Proyek ini bertujuan untuk membangun model prediktif sederhana menggunakan Simple Linear Regression guna memprediksi nilai GPA mahasiswa berdasarkan skor SAT (Scholastic Assessment Test) mereka. SAT sering digunakan sebagai indikator kemampuan akademik awal, dan proyek ini mencoba mengukur sejauh mana skor SAT dapat menjadi prediktor linier terhadap prestasi akhir mahasiswa dalam bentuk GPA.

# %% [markdown]
# ## Tujuan
# * Menguji apakah ada hubungan linier antara SAT scores dan GPA.
# * Melatih model regresi linear sederhana.
# * Mengukur performa model menggunakan metrik evaluasi seperti MAE, MSE, RMSE, dan R² Score.
# * Menyediakan visualisasi hubungan antara fitur dan target.
#
# ## Format Dataset
# * Fitur input (X): SAT_Score (skor ujian SAT siswa)
# * Target/output (y): GPA (nilai indeks prestasi mahasiswa)
# * Format: CSV atau DataFrame sederhana dengan dua kolom numerik
#
# Source : [Klik disini](https://www.kaggle.com/datasets/japondo/simple-linear-regression)
#
# ## Stack & Tools
# * Bahasa: Python
# * Library: pandas, numpy, matplotlib, seaborn, scikit-learn

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import dataset

# %%
dataframe = pd.read_csv('dataset/gpa.csv')
# x = np.array([dataframe['Age']]).reshape(-1, 1)
# x = np.array([dataframe['Age']])
# x = dataframe.iloc[:, 0].values.reshape(-1,1)
x = dataframe.iloc[:, :-1].values

# ubah meter ke centimeter
# dataframe['Height'] = (dataframe['Height'] * 100).astype(int)
# y = np.array([dataframe['Height']])
y = dataframe.iloc[:, -1].values
# y = dataframe['Height']
# print(y)

# %% [markdown]
# ## Splitting dataset into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)
# print(y_train)

# %% [markdown]
# ## Training data with simple linear regression model

# %%
from sklearn.linear_model import LinearRegression
regresi = LinearRegression()
regresi.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Make predict result

# %%
y_pred = regresi.predict(x_test)
# print(y_pred, y_test)

# %% [markdown]
# # Visualize the training result

# %%
# merah = data yg di training
plt.scatter(x_train, y_train, color='red')
x_predict_training = regresi.predict(x_train)
plt.plot(x_train, x_predict_training, color='blue')
plt.title('SBMPTN VS IPK (Training set)')

plt.xlabel('SBMPTN')
plt.ylabel('IPK')

plt.show()

# %% [markdown]
# ## Visualize the predicg result

# %%
plt.scatter(x_test, y_test, color='red')
x_predict_testing = regresi.predict(x_test)
plt.plot(x_train, x_predict_training, color='blue')
plt.title('SBMPTN VS IPK (Testing set)')

plt.xlabel('SBMPTN')
plt.ylabel('IPK')

plt.show()

# %% [markdown]
# ## Evaluasi

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(dataframe.corr(), annot=True, cmap='coolwarm')
plt.title("Korelasi antar fitur")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(y_test, y_pred)
mse = np.sqrt(mean_squared_error(y_test, y_pred))
rmse = np.sqrt(mse)

# Cetak hasilnya
print(f"MAE  : {mae:.2f}")
print(f"MSE  : {mse:.2f}")
print(f"RMSE : {rmse:.2f}")
# Out:
# MAE  : 0.18
# MSE  : 0.21
# RMSE : 0.46
